# %%
import pandas as pd
df = pd.read_html('http://www.espn.com/nba/team/schedule/_/name/bos')

# %%
s = df[0]
s.head()
# Out:
#                               0              1         2    3  \
# 0  2018 Regular Season Schedule            NaN       NaN  NaN
# 1                       OCTOBER       OPPONENT    RESULT  W-L
# 2                   Tue, Oct 17     @Cleveland   L102-99  0-1
# 3                   Wed, Oct 18    vsMilwaukee  L108-100  0-2
# 4                   Fri, Oct 20  @Philadelphia   W102-92  1-2
#
#                      4                    5               6
# 0                  NaN                  NaN             NaN
# 1            HI POINTS          HI REBOUNDS      HI ASSISTS
# 2          L. James 29          L. James 16    K. Irving 10
# 3  G. Antetokounmpo 37  G. Antetokounmpo 13  K. Middleton 6
# 4         K. Irving 21         J. Embiid 14    B. Simmons 5

# %%
df{:,1}
# Out:
#   File "<ipython-input-5-d599240711c7>", line 1
#     df{:,1}
#       ^
# SyntaxError: invalid syntax

# %%
df[0:1]
# Out:
# [                               0                1            2      3  \
#  0   2018 Regular Season Schedule              NaN          NaN    NaN
#  1                        OCTOBER         OPPONENT       RESULT    W-L
#  2                    Tue, Oct 17       @Cleveland      L102-99    0-1
#  3                    Wed, Oct 18      vsMilwaukee     L108-100    0-2
#  4                    Fri, Oct 20    @Philadelphia      W102-92    1-2
#  5                    Tue, Oct 24      vsNY Knicks      W110-89    2-2
#  6                    Thu, Oct 26       @Milwaukee       W96-89    3-2
#  7                    Sat, Oct 28           @Miami       W96-90    4-2
#  8                    Mon, Oct 30    vsSan Antonio      W108-94    5-2
#  9                       NOVEMBER         OPPONENT       RESULT    W-L
#  10                    Wed, Nov 1     vsSacramento      W113-86    6-2
#  11                    Fri, Nov 3   @Oklahoma City      W101-94    7-2
# ...

# %%
df[0].columns =['A','B','C','D','E','F','G']

# %%
s.head()
s.columns = ['Date','Location','Results','W/L','Top Scorer','Top Rebounder','Top Assist']
s.head()
# Out:
#                            Date       Location   Results  W/L  \
# 0  2018 Regular Season Schedule            NaN       NaN  NaN
# 1                       OCTOBER       OPPONENT    RESULT  W-L
# 2                   Tue, Oct 17     @Cleveland   L102-99  0-1
# 3                   Wed, Oct 18    vsMilwaukee  L108-100  0-2
# 4                   Fri, Oct 20  @Philadelphia   W102-92  1-2
#
#             Top Scorer        Top Rebounder      Top Assist
# 0                  NaN                  NaN             NaN
# 1            HI POINTS          HI REBOUNDS      HI ASSISTS
# 2          L. James 29          L. James 16    K. Irving 10
# 3  G. Antetokounmpo 37  G. Antetokounmpo 13  K. Middleton 6
# 4         K. Irving 21         J. Embiid 14    B. Simmons 5

# %%
s['Results']= s['Results'].str.split('-', expand = True)

# %%
s
# Out:
#                             Date         Location    Results    W/L  \
# 0   2018 Regular Season Schedule              NaN        NaN    NaN
# 1                        OCTOBER         OPPONENT     RESULT    W-L
# 2                    Tue, Oct 17       @Cleveland       L102    0-1
# 3                    Wed, Oct 18      vsMilwaukee       L108    0-2
# 4                    Fri, Oct 20    @Philadelphia       W102    1-2
# 5                    Tue, Oct 24      vsNY Knicks       W110    2-2
# 6                    Thu, Oct 26       @Milwaukee        W96    3-2
# 7                    Sat, Oct 28           @Miami        W96    4-2
# 8                    Mon, Oct 30    vsSan Antonio       W108    5-2
# 9                       NOVEMBER         OPPONENT     RESULT    W-L
# 10                    Wed, Nov 1     vsSacramento       W113    6-2
# 11                    Fri, Nov 3   @Oklahoma City       W101    7-2
# 12                    Sun, Nov 5         @Orlando       W104    8-2
# ...
