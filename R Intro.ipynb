# %%
library(dplyr)     #for some functions such as mutate
library(dslabs)    # for some dataset such as murders
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
murders
# Out:
#    state                abb region        population total
# 1  Alabama              AL  South          4779736    135
# 2  Alaska               AK  West            710231     19
# 3  Arizona              AZ  West           6392017    232
# 4  Arkansas             AR  South          2915918     93
# 5  California           CA  West          37253956   1257
# 6  Colorado             CO  West           5029196     65
# 7  Connecticut          CT  Northeast      3574097     97
# 8  Delaware             DE  South           897934     38
# 9  District of Columbia DC  South           601723     99
# 10 Florida              FL  South         19687653    669
# 11 Georgia              GA  South          9920000    376
# 12 Hawaii               HI  West           1360301      7
# 13 Idaho                ID  West           1567582     12
# 14 Illinois             IL  North Central 12830632    364
# 15 Indiana              IN  North Central  6483802    142
# 16 Iowa                 IA  North Central  3046355     21
# 17 Kansas               KS  North Central  2853118     63
# 18 Kentucky             KY  South          4339367    116
# 19 Louisiana            LA  South          4533372    351
# 20 Maine                ME  Northeast      1328361     11
# 21 Maryland             MD  South          5773552    293
# 22 Massachusetts        MA  Northeast      6547629    118
# 23 Michigan             MI  North Central  9883640    413
# 24 Minnesota            MN  North Central  5303925     53
# 25 Mississippi          MS  South          2967297    120
# 26 Missouri             MO  North Central  5988927    321
# 27 Montana              MT  West            989415     12
# 28 Nebraska             NE  North Central  1826341     32
# 29 Nevada               NV  West           2700551     84
# 30 New Hampshire        NH  Northeast      1316470      5
# 31 New Jersey           NJ  Northeast      8791894    246
# 32 New Mexico           NM  West           2059179     67
# 33 New York             NY  Northeast     19378102    517
# 34 North Carolina       NC  South          9535483    286
# 35 North Dakota         ND  North Central   672591      4
# 36 Ohio                 OH  North Central 11536504    310
# 37 Oklahoma             OK  South          3751351    111
# 38 Oregon               OR  West           3831074     36
# 39 Pennsylvania         PA  Northeast     12702379    457
# 40 Rhode Island         RI  Northeast      1052567     16
# 41 South Carolina       SC  South          4625364    207
# 42 South Dakota         SD  North Central   814180      8
# 43 Tennessee            TN  South          6346105    219
# 44 Texas                TX  South         25145561    805
# 45 Utah                 UT  West           2763885     22
# 46 Vermont              VT  Northeast       625741      2
# 47 Virginia             VA  South          8001024    250
# 48 Washington           WA  West           6724540     93
# 49 West Virginia        WV  South          1852994     27
# 50 Wisconsin            WI  North Central  5686986     97
# 51 Wyoming              WY  West            563626      5

# %%
install.packages("dpylr")
# Out:
# Warning message:
# "unable to access index for repository https://mran.microsoft.com/snapshot/2017-09-01/src/contrib:
#   cannot open URL 'https://mran.microsoft.com/snapshot/2017-09-01/src/contrib/PACKAGES'"Warning message:
# "unable to access index for repository http://www.stats.ox.ac.uk/pub/RWin/src/contrib:
#   cannot open URL 'http://www.stats.ox.ac.uk/pub/RWin/src/contrib/PACKAGES'"Warning message:
# "package 'dpylr' is not available (for R version 3.4.3)"Warning message:
# "unable to access index for repository https://mran.microsoft.com/snapshot/2017-09-01/bin/windows/contrib/3.4:
#   cannot open URL 'https://mran.microsoft.com/snapshot/2017-09-01/bin/windows/contrib/3.4/PACKAGES'"Warning message:
# "unable to access index for repository http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/3.4:
#   cannot open URL 'http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/3.4/PACKAGES'"

# %%
# Below, write code to calculate the sum of the first 100 integers

n<-1:100
sum(n)
# Out:
# [1] 5050

# %%
library(dplyr)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
# find the structure of the table

str(murders)
# Out:
# Error in str(murders): object 'murders' not found
# Traceback:
#
# 1. str(murders)

# %%
# find column names

names(murders)
# Out:
# [1] "state"      "abb"        "region"     "population" "total"

# %%
# find the class of the column
class(murders$total)
# Out:
# [1] "numeric"

# %%
# We extract the population like this:
p <- murders$population

# This is how we do the same with the square brackets:
o <- murders[["population"]] 

# We can confirm these two are the same
identical(o, p)
# Out:
# [1] TRUE

# %%
#if a class is a factor(category) then you can use levels to see the grouping
class(murders$region)

levels(murders$region)
# Out:
# [1] "factor"
# [1] "Northeast"     "South"         "North Central" "West"

# %%
# Here is an example of what the table function does
x <- c("a", "a", "b", "b", "b", "c")
table(x)

#example from murder table
table(murders$region)
# Out:
# x
# a b c
# 2 3 1
#     Northeast         South North Central          West
#             9            17            12            13

# %%
#Numeric Vectors



#A vector is a series of values, all of the same type. They are the most basic data type in R and can hold numeric data, character data, or logical data. In R, you can create a vector with the combine function c(). You place the vector elements separated by a comma between the parentheses. For example a numeric vector would look something like this: 
cost <- c(50, 75, 90, 100, 150)

# %%
# Associate the cost values with its corresponding food item
cost <- c(50, 75, 90, 100, 150)
food <- c("pizza", "burgers", "salads", "cheese", "pasta")
names(cost) <- food


# cost of the last 3 items in our food list:
cost[3:5]

#To access the cost of pizza (1st) and pasta (5th food item) in our list, the code would be:
cost[c(1,5)]
# Out:
# salads cheese  pasta
#     90    100    150

# %%
# Create a vector m of integers that starts at 32 and ends at 99.
m <- 32:99

# seq doing the same thing
n <- seq(32,99)

# check
identical(m,n)

# Determine the length of object m.
length(m)


# Create a vector with the multiples of 7, smaller than 50.
seq(7, 49, 7) 


#produces the numbers 0, 25, 50, 75, 100. 
seq(0, 100, length.out = 5)
# Out:
# [1] TRUE
# [1] 68
# [1]  7 14 21 28 35 42 49
# [1]   0  25  50  75 100

# %%
# Define the vector x
x <- c(1, 3, 5,"a")

# Note that the x is character vector
class(x)

# Typecast the vector to get an integer vector
# You will get a warning but that is ok
x<-as.numeric(x)
# Out:
# [1] "character"
# Warning message in eval(expr, envir, enclos):
# "NAs introduced by coercion"

# %%
# Access the `state` variable and store it in an object 
states <- murders$state 

# Sort the object alphabetically and redefine the object 
states <- sort(states) 

# Report the first alphabetical value  
states[1]

# Access population values from the dataset and store it in pop
pop = murders$population

# Sort the object and save it in the same object 

pop <- sort(pop)
pop

# Report the smallest population size 
pop[1]
# Out:
# [1] "Alabama"
#  [1]   563626   601723   625741   672591   710231   814180   897934   989415
#  [9]  1052567  1316470  1328361  1360301  1567582  1826341  1852994  2059179
# [17]  2700551  2763885  2853118  2915918  2967297  3046355  3574097  3751351
# [25]  3831074  4339367  4533372  4625364  4779736  5029196  5303925  5686986
# [33]  5773552  5988927  6346105  6392017  6483802  6547629  6724540  8001024
# [41]  8791894  9535483  9883640  9920000 11536504 12702379 12830632 19378102
# [49] 19687653 25145561 37253956
# [1] 563626

# %%
# Access population from the dataset and store it in pop
pop <- murders$population

# Use the command order, to order pop and store in object o
o <- order(pop)
o
# Find the index number of the entry with the smallest population size
o[1]
# Out:
#  [1] 51  9 46 35  2 42  8 27 40 30 20 12 13 28 49 32 29 45 17  4 25 16  7 37 38
# [26] 18 19 41  1  6 24 50 21 26 43  3 15 22 48 47 31 34 23 11 36 39 14 33 10 44
# [51]  5
# [1] 51

# %%
# Find the smallest value for variable total 
which.min(murders$total)

# Find the smallest value for population
which.min(murders$population)

# %%
# Define the variable i to be the index of the smallest state
i <- which.min(murders$population)

# Define variable states to hold the states

states <- murders$state

# Use the index you just defined to find the state with the smallest population
states[i]

# %%
# Store temperatures in an object 
temp <- c(35, 88, 42, 84, 81, 30)

# Store city names in an object 
city <- c("Beijing", "Lagos", "Paris", "Rio de Janeiro", "San Juan", "Toronto")

# Create data frame with city names and temperature 
city_temps <- data.frame(name = city, temperature = temp)

# Define a variable states to be the state names 
states <- murders$state

# Define a variable ranks to determine the population size ranks 

ranks <- rank(murders$population)

# %%
# Define a variable states to be the state names from the murders data frame

states<-murders$state

# Define a variable ranks to determine the population size ranks 
ranks<-rank(murders$population)

# Define a variable ind to store the indexes needed to order the population values
ind<-order(murders$population)

# Create a data frame my_df with the state name and its rank and ordered from least populous to most 
my_df<- data.frame(name = states[ind] ,rank = ranks[ind])

# %%
# Using new dataset 
library(dslabs)
data(na_example)

# Checking the structure 
str(na_example)

# Find out the mean of the entire dataset 
mean(na_example)

# Use is.na to create a logical index ind that tells which entries are NA

ind<-is.na(na_example)

# Determine how many NA ind has using the sum function
sum(ind)

# %%
# Note what we can do with the ! operator
x <- c(1, 2, 3)
ind <- c(FALSE, TRUE, FALSE)
x[!ind]

# Create the ind vector
library(dslabs)
data(na_example)
ind <- is.na(na_example)

# We saw that this gives an NA
mean(na_example)

# Compute the average, for entries of na_example that are not NA 
mean(na_example[!ind])

# %%
# Create a data frame `city_temps` 
city_temps <- data.frame(name = city, temperature = temp)

# %%
x <- c(88, 100, 83, 92, 94)
x[rank(x)]
# Out:
# [1] 100  94  88  83  92

# %%
# Use filter to create a new data frame no_south
no_south <- filter(murders,region!="South")
# Use nrow() to calculate the number of rows
nrow(no_south)
# Out:
# [1] 34

# %%
# Create a new data frame called murders_nw with only the states from the northeast and the west
murders_nw<-filter(murders,region %in% c("Northeast","West"))
# Number of states (rows) in this category 
nrow(murders_nw)
# Out:
# [1] 22

# %%
# add the rate column
murders <- mutate(murders, rate =  total / population * 100000, rank = rank(-rate))

# Create a table, call it my_states, that satisfies both the conditions 
my_states<-filter(murders,region %in% c("Northeast","West") & rate < 1)
# Use select to show only the state name, the murder rate and the rank
select(my_states,state,rate,rank)

# %%
# Load library
library(dplyr)

## Define the rate column
murders <- mutate(murders, rate =  total / population * 100000, rank = rank(-rate))


# show the result and only include the state, rate, and rank columns, all in one line
filter(murders,region %in% c("Northeast","West") & rate < 1) %>% select(state,rate,rank)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
# Error in mutate(murders, rate = total/population * 1e+05, rank = rank(-rate)): object 'murders' not found
# Traceback:
#
# 1. mutate(murders, rate = total/population * 1e+05, rank = rank(-rate))

# %%
# Loading the libraries
library(dplyr)
data(murders)

# Create new data frame called my_states (with specifications in the instructions)
 
my_states <- murders %>% mutate(rate =  total / population * 100000, rank = rank(-rate)) %>% filter(region %in% c("Northeast","West") & rate < 1) %>% select(state,rate,rank)
# Out:
# Error in mutate_impl(.data, dots): Column `murders` must be length 51 (the number of rows) or one, not 5
# Traceback:
#
# 1. murders %>% mutate(murders, rate = total/population * 1e+05,
#  .     rank = rank(-rate))
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
# 9. mutate(., murders, rate = total/population * 1e+05, rank = rank(-rate))
# 10. mutate.data.frame(., murders, rate = total/population * 1e+05,
#   .     rank = rank(-rate))
# 11. as.data.frame(mutate(tbl_df(.data), ...))
# 12. mutate(tbl_df(.data), ...)
# 13. mutate.tbl_df(tbl_df(.data), ...)
# 14. mutate_impl(.data, dots)

# %%
# Load the datasets and define some variables
library(dslabs)
data(murders)

population_in_millions <- murders$population/10^6
total_gun_murders <- murders$total

plot(population_in_millions, total_gun_murders)

# Transform population using the log10 transformation and save to object log10_population
log10_population = log(murders$population,10)

# Transform total gun murders using log10 transformation and save to object log10_total_gun_murders
log10_total_gun_murders = log(murders$total,10)

# Create a scatterplot with the log scale transformed population and murders
plot(log10_population,log10_total_gun_murders)
# Out:
# [1] 4

# %%
# Create a boxplot of state populations by region for the murders dataset
boxplot(population~region, data=murders)

# %%
# Store the population in millions and save to population_in_millions 
population_in_millions <- murders$population/10^6


# Create a histogram of this variable
hist(population_in_millions)

# %%
# Create the ind vector
library(dslabs)
data(na_example)
ind <- !is.na(na_example)

# %%
ind
# Out:
#    [1]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE
#   [13]  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#   [25]  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#   [37]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#   [49]  TRUE FALSE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE
#   [61]  TRUE  TRUE  TRUE  TRUE FALSE FALSE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE
#   [73]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#   [85]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE
#   [97]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [109]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE
#  [121]  TRUE  TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE  TRUE
#  [133]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE  TRUE  TRUE
#  [145]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE
#  [157]  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE
#  [169] FALSE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE
#  [181]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE  TRUE  TRUE
#  [193]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE
#  [205] FALSE  TRUE FALSE FALSE  TRUE  TRUE  TRUE FALSE  TRUE FALSE  TRUE  TRUE
#  [217]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [229]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE
#  [241] FALSE  TRUE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [253] FALSE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [265] FALSE  TRUE FALSE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [277]  TRUE  TRUE FALSE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE
#  [289]  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE
#  [301]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE
#  [313]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [325] FALSE FALSE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [337]  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE
#  [349]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [361] FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [373]  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [385]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE FALSE  TRUE
#  [397] FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE
#  [409]  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [421]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [433]  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE
#  [445]  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [457]  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE
#  [469]  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [481]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE
#  [493]  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [505] FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [517]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE
#  [529]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE FALSE  TRUE
#  [541]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [553] FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE
#  [565]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE
#  [577]  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [589] FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE
#  [601]  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE
#  [613]  TRUE  TRUE  TRUE FALSE  TRUE FALSE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE
#  [625]  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE FALSE  TRUE  TRUE FALSE
#  [637]  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [649]  TRUE  TRUE  TRUE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [661]  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE FALSE  TRUE  TRUE  TRUE  TRUE
#  [673]  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE
#  [685]  TRUE  TRUE FALSE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE FALSE  TRUE
#  [697]  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [709]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [721]  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [733]  TRUE FALSE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [745] FALSE FALSE FALSE FALSE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE FALSE
#  [757]  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE
#  [769]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [781]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE  TRUE  TRUE  TRUE
#  [793]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [805]  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [817]  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE
#  [829]  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE
#  [841]  TRUE  TRUE FALSE FALSE FALSE  TRUE  TRUE  TRUE FALSE FALSE  TRUE  TRUE
#  [853] FALSE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [865]  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [877]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE
#  [889]  TRUE  TRUE  TRUE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [901]  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE FALSE  TRUE FALSE  TRUE
#  [913]  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE
#  [925] FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [937]  TRUE  TRUE FALSE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [949]  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [961]  TRUE FALSE  TRUE  TRUE FALSE FALSE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE
#  [973]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [985]  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#  [997]  TRUE  TRUE FALSE  TRUE

# %%
log(8)
# Out:
# [1] 2.079442

# %%
h = c(1,2,3,4,'na')

# %%
x <- as.numeric(h)
# Out:
# Warning message in eval(expr, envir, enclos):
# "NAs introduced by coercion"

# %%
is.na(x)
# Out:
# [1] FALSE FALSE FALSE FALSE  TRUE

# %%
library(dslabs)
data(murders)

# %%
murders
# Out:
#    state                abb region        population total
# 1  Alabama              AL  South          4779736    135
# 2  Alaska               AK  West            710231     19
# 3  Arizona              AZ  West           6392017    232
# 4  Arkansas             AR  South          2915918     93
# 5  California           CA  West          37253956   1257
# 6  Colorado             CO  West           5029196     65
# 7  Connecticut          CT  Northeast      3574097     97
# 8  Delaware             DE  South           897934     38
# 9  District of Columbia DC  South           601723     99
# 10 Florida              FL  South         19687653    669
# 11 Georgia              GA  South          9920000    376
# 12 Hawaii               HI  West           1360301      7
# 13 Idaho                ID  West           1567582     12
# 14 Illinois             IL  North Central 12830632    364
# 15 Indiana              IN  North Central  6483802    142
# 16 Iowa                 IA  North Central  3046355     21
# 17 Kansas               KS  North Central  2853118     63
# 18 Kentucky             KY  South          4339367    116
# 19 Louisiana            LA  South          4533372    351
# 20 Maine                ME  Northeast      1328361     11
# 21 Maryland             MD  South          5773552    293
# 22 Massachusetts        MA  Northeast      6547629    118
# 23 Michigan             MI  North Central  9883640    413
# 24 Minnesota            MN  North Central  5303925     53
# 25 Mississippi          MS  South          2967297    120
# 26 Missouri             MO  North Central  5988927    321
# 27 Montana              MT  West            989415     12
# 28 Nebraska             NE  North Central  1826341     32
# 29 Nevada               NV  West           2700551     84
# 30 New Hampshire        NH  Northeast      1316470      5
# 31 New Jersey           NJ  Northeast      8791894    246
# 32 New Mexico           NM  West           2059179     67
# 33 New York             NY  Northeast     19378102    517
# 34 North Carolina       NC  South          9535483    286
# 35 North Dakota         ND  North Central   672591      4
# 36 Ohio                 OH  North Central 11536504    310
# 37 Oklahoma             OK  South          3751351    111
# 38 Oregon               OR  West           3831074     36
# 39 Pennsylvania         PA  Northeast     12702379    457
# 40 Rhode Island         RI  Northeast      1052567     16
# 41 South Carolina       SC  South          4625364    207
# 42 South Dakota         SD  North Central   814180      8
# 43 Tennessee            TN  South          6346105    219
# 44 Texas                TX  South         25145561    805
# 45 Utah                 UT  West           2763885     22
# 46 Vermont              VT  Northeast       625741      2
# 47 Virginia             VA  South          8001024    250
# 48 Washington           WA  West           6724540     93
# 49 West Virginia        WV  South          1852994     27
# 50 Wisconsin            WI  North Central  5686986     97
# 51 Wyoming              WY  West            563626      5

# %%
filter(murders, state == 'Alaska') %>% mutate(TIME =total*100)
# Out:
#   state  abb region population total TIME
# 1 Alaska AK  West   710231     19    1900

# %%
library (stringr)

# %%
h = c("my name",'no','myyy','my book')

# %%
sum(str_detect(h,"my"))
# Out:
# [1] 3

# %%
n = "^[5-9]'\\d{1,2}$"

# %%
n2 = "[5-9]'\\d{1,2}$"

# %%
h = c("a")

# %%
str_detect(fruit,"[a-c]")
# Out:
#  [1]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [13]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [25]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE
# [37] FALSE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE FALSE FALSE  TRUE  TRUE  TRUE
# [49]  TRUE  TRUE  TRUE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE
# [61]  TRUE  TRUE FALSE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [73]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE

# %%
str_extract(fruit,"[a-c]")
# Out:
#  [1] "a" "a" "a" "b" "b" "b" "b" "b" "b" "b" "b" "b" "c" "c" "c" "c" "c" "c" "c"
# [20] "c" "c" "c" "c" "a" "a" "a" "a" "a" "b" "a" NA  "b" "b" "a" "a" "a" NA  "c"
# [39] "a" "a" "b" NA  "a" NA  NA  "a" "c" "a" "a" "b" "c" NA  NA  "a" "a" "a" "a"
# [58] "a" "a" NA  "a" "a" NA  "a" NA  "a" "c" "a" "a" "a" "c" "c" "a" "a" "a" "a"
# [77] "a" "a" NA  "a"

# %%
str_subset(fruit,"[a-c]")
# Out:
#  [1] "apple"             "apricot"           "avocado"
#  [4] "banana"            "bell pepper"       "bilberry"
#  [7] "blackberry"        "blackcurrant"      "blood orange"
# [10] "blueberry"         "boysenberry"       "breadfruit"
# [13] "canary melon"      "cantaloupe"        "cherimoya"
# [16] "cherry"            "chili pepper"      "clementine"
# [19] "cloudberry"        "coconut"           "cranberry"
# [22] "cucumber"          "currant"           "damson"
# [25] "date"              "dragonfruit"       "durian"
# [28] "eggplant"          "elderberry"        "feijoa"
# [31] "goji berry"        "gooseberry"        "grape"
# [34] "grapefruit"        "guava"             "huckleberry"
# [37] "jackfruit"         "jambul"            "jujube"
# [40] "kumquat"           "loquat"            "lychee"
# [43] "mandarine"         "mango"             "mulberry"
# [46] "nectarine"         "orange"            "pamelo"
# [49] "papaya"            "passionfruit"      "peach"
# [52] "pear"              "physalis"          "pineapple"
# [55] "pomegranate"       "purple mangosteen" "quince"
# [58] "raisin"            "rambutan"          "raspberry"
# [61] "redcurrant"        "rock melon"        "salal berry"
# [64] "satsuma"           "star fruit"        "strawberry"
# [67] "tamarillo"         "tangerine"         "watermelon"

# %%
b <- data.frame(name = fruit)
b
# Out:
#     name
# 1   apple
# 2   apricot
# 3   avocado
# 4   banana
# 5   bell pepper
# 6   bilberry
# 7   blackberry
# 8   blackcurrant
# 9   blood orange
# 10  blueberry
# 11  boysenberry
# 12  breadfruit
# 13  canary melon
# 14  cantaloupe
# 15  cherimoya
# 16  cherry
# 17  chili pepper
# 18  clementine
# 19  cloudberry
# 20  coconut
# 21  cranberry
# 22  cucumber
# 23  currant
# 24  damson
# 25  date
# 26  dragonfruit
# 27  durian
# 28  eggplant
# 29  elderberry
# 30  feijoa
# ... ...
# 51  nectarine
# 52  nut
# 53  olive
# 54  orange
# 55  pamelo
# 56  papaya
# 57  passionfruit
# 58  peach
# 59  pear
# 60  persimmon
# 61  physalis
# 62  pineapple
# 63  plum
# 64  pomegranate
# 65  pomelo
# 66  purple mangosteen
# 67  quince
# 68  raisin
# 69  rambutan
# 70  raspberry
# 71  redcurrant
# 72  rock melon
# 73  salal berry
# 74  satsuma
# 75  star fruit
# 76  strawberry
# 77  tamarillo
# 78  tangerine
# 79  ugli fruit
# 80  watermelon

# %%
filter(b,str_sub(name,1,1)=="r")
# Out:
#   name
# 1 raisin
# 2 rambutan
# 3 raspberry
# 4 redcurrant
# 5 rock melon

# %%
fruit
# Out:
#  [1] "apple"             "apricot"           "avocado"
#  [4] "banana"            "bell pepper"       "bilberry"
#  [7] "blackberry"        "blackcurrant"      "blood orange"
# [10] "blueberry"         "boysenberry"       "breadfruit"
# [13] "canary melon"      "cantaloupe"        "cherimoya"
# [16] "cherry"            "chili pepper"      "clementine"
# [19] "cloudberry"        "coconut"           "cranberry"
# [22] "cucumber"          "currant"           "damson"
# [25] "date"              "dragonfruit"       "durian"
# [28] "eggplant"          "elderberry"        "feijoa"
# [31] "fig"               "goji berry"        "gooseberry"
# [34] "grape"             "grapefruit"        "guava"
# [37] "honeydew"          "huckleberry"       "jackfruit"
# [40] "jambul"            "jujube"            "kiwi fruit"
# [43] "kumquat"           "lemon"             "lime"
# [46] "loquat"            "lychee"            "mandarine"
# [49] "mango"             "mulberry"          "nectarine"
# [52] "nut"               "olive"             "orange"
# [55] "pamelo"            "papaya"            "passionfruit"
# [58] "peach"             "pear"              "persimmon"
# [61] "physalis"          "pineapple"         "plum"
# [64] "pomegranate"       "pomelo"            "purple mangosteen"
# [67] "quince"            "raisin"            "rambutan"
# [70] "raspberry"         "redcurrant"        "rock melon"
# [73] "salal berry"       "satsuma"           "star fruit"
# [76] "strawberry"        "tamarillo"         "tangerine"
# [79] "ugli fruit"        "watermelon"

# %%
str_sub("ronny",1,3)
# Out:
# [1] "ron"

# %%
str_replace("ronaa","a","-")
# Out:
# [1] "ron-a"

# %%
str_replace_all("ronaa","a","-")
# Out:
# [1] "ron--"

# %%
str_subset("ronny","o")
# Out:
# [1] "ronny"

# %%
str_extract("ronony","o")
# Out:
# [1] "o"

# %%
str_sub("ronny",1,2)
# Out:
# [1] "ro"

# %%
install.packages("knitr")
# Out:
# package 'knitr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\m118954.CORPAU\AppData\Local\Temp\Rtmp23ZVhY\downloaded_packages

# %%
pattern1 <- "^[4-7]'\\d{1,2}\"$" 
pattern2 <- "^[4-7]'\\d{1,2}$"

# %%
h = c('5\'7"')

# %%
str_detect(h,pattern1)
str_detect(h,pattern2)
# Out:
# [1] TRUE
# [1] FALSE

# %%
sum(str_detect(h,pattern1))
sum(str_detect(h,pattern2))
# Out:
# [1] 1
# [1] 0

# %%
h
# Out:
# [1] "5'7\""
